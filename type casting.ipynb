# %%
# type casting 


int(2.3)
# Out:
# 2

# %%
int(2.3,3.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 int(2.3,3.4)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int(10)
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
int(10.9)
# Out:
# 10

# %%
int(5)
# Out:
# 5

# %%
int("100")
# Out:
# 100

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(-7)
# Out:
# -7

# %%
int("10.5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 int("10.5")
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
int("abc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 int("abc")
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
int[1,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 int[1,2]
#
# TypeError: type 'int' is not subscriptable

# %%
# float 

float (20)
# Out:
# 20.0

# %%
float(20.0)
# Out:
# 20.0

# %%
float (True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float (1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 float (1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float("10")
# Out:
# 10.0

# %%
float ("indu")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 float ("indu")
#
# ValueError: could not convert string to float: 'indu'

# %%
float("ten")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 float("ten")
#
# ValueError: could not convert string to float: 'ten'

# %%
float("10")
# Out:
# 10.0

# %%
# bool
# all datatypes in bool is possible 

bool(True)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
bool(2)
# Out:
# True

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(ten)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 bool(ten)
#
# NameError: name 'ten' is not defined

# %%
bool("10")
# Out:
# True

# %%
bool("ten")
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool(2.0)
# Out:
# True

# %%
#complex

complex(10)
# Out:
# (10+0j)

# %%
complex()
# Out:
# 0j

# %%
complex("10+2j")
# Out:
# (10+2j)

# %%
complex("ten")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 complex("ten")
#
# ValueError: complex() arg is a malformed string

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3+2.4)
# Out:
# (4.699999999999999+0j)

# %%
complex(2.3, 2.4)
# Out:
# (2.3+2.4j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex("indu,bindu")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 complex("indu,bindu")
#
# ValueError: complex() arg is a malformed string

# %%
complex(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 complex(true)
#
# NameError: name 'true' is not defined

# %%
complex("True")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 complex("True")
#
# ValueError: complex() arg is a malformed string

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
# string
 
str("indu")
# Out:
# 'indu'

# %%
str("10")
# Out:
# '10'

# %%
str("True")
# Out:
# 'True'

# %%
str("False")
# Out:
# 'False'

# %%
str(1.0)
# Out:
# '1.0'

# %%
str(10)
# Out:
# '10'

# %%
str(10+3j)
# Out:
# '(10+3j)'

# %%
str(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 str(2,3)
#
# TypeError: str() argument 'encoding' must be str, not int
